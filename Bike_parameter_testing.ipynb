# %% [markdown]
# # Parameter testing
#
# If not already done, please pay attention to the Requirements and Preparation of the file "Bike.ipynb".

# %% [markdown]
# ## Select parameter and write in file.

# %%
import os
import deformetrica as dfca
from math import sqrt
import pandas as pd
import torch 
from dtaidistance import dtw_ndim
import xlsxwriter

#paramter
attachmentType = 'varifold' # 'current'
kernelWidth = 10
deformationKernelWidth = 10
noiseStd = 0.1
numberOfTimePoints = 11
template = 'mask_03' #name of file without file extension
templateName = template + '.vtk'
initialControlPointsName = template + '_initial_control_points.txt'

#write file
data_path_results = "results/"
data_path_control_points = "images/"
output_file = os.path.join(data_path_results, 'results_parameter_testing.txt' )
data_base_control_points = os.path.join(data_path_control_points, 'mask_initial_control_points/')
os.makedirs(data_path_results, exist_ok=True)

f = open(output_file, "a")
f.write("###########################################################\n")
f.write("parameter:\n")
f.write("attachmentType: " + attachmentType + "\n")
f.write("kernelWidth: " + str(kernelWidth) + "\n")
f.write("deformationKernelWidth: " + str(deformationKernelWidth) + "\n")
f.write("noiseStd: " + str(noiseStd) + "\n")
f.write("numberOfTimePoints: " + str(numberOfTimePoints) + "\n")
f.write("templateName: " + templateName + "\n")
f.write("\n")
# Out:
# 1

# %% [markdown]
# ## Run Deformetrica

# %%
data_path_images = "images/"
data_base = os.path.join(data_path_images, 'mask_vtk/')

iteration_status_dictionaries = []
def estimator_callback(status_dict):
    iteration_status_dictionaries.append(status_dict)
    return True

# instantiate a Deformetrica object
deformetrica = dfca.Deformetrica(output_dir='output', verbosity='INFO')

dataset_specifications = {
        'dataset_filenames': [
            [{'bike': os.path.join(data_base, 'mask_01.vtk')}],
            [{'bike': os.path.join(data_base, 'mask_02.vtk')}],
            [{'bike': os.path.join(data_base, 'mask_03.vtk')}],
            [{'bike': os.path.join(data_base, 'mask_04.vtk')}],
            [{'bike': os.path.join(data_base, 'mask_05.vtk')}]],
        'subject_ids': ['mask_01', 'mask_02', 'mask_03', 'mask_04', 'mask_05'],
    }
template_specifications = {
        'bike': {'deformable_object_type': 'polyline',
                  'kernel_type': 'torch', 'kernel_width': kernelWidth,
                  'noise_std': noiseStd,
                  'filename': os.path.join(data_base, templateName),
                  'attachment_type': attachmentType}
    }
estimator_options={'optimization_method_type': 'GradientAscent', 'initial_step_size': 1.,
                               'max_iterations': 100, 'max_line_search_iterations': 10, 'callback': estimator_callback}

# perform a deterministic atlas estimation
model = deformetrica.estimate_deterministic_atlas(template_specifications, dataset_specifications,
                                                    estimator_options=estimator_options,
                                                    model_options={'deformation_kernel_type': 'torch', 'deformation_kernel_width': deformationKernelWidth, 
                                                                               'dtype': 'float32', 'number_of_time_points': numberOfTimePoints, 
                                                                               'initial_control_points': os.path.join(data_base_control_points, initialControlPointsName)})
# Out:
# Logger has been set to: INFO
# OMP_NUM_THREADS was not found in environment variables. An automatic value will be set.
# OMP_NUM_THREADS will be set to 2
# >> No specified state-file. By default, Deformetrica state will by saved in file: output/deformetrica-state.p.
# >> Removing the pre-existing state file with same path.
# >> Reading 200 initial control points from file images/mask_initial_control_points/mask_03_initial_control_points.txt.
# >> Momenta initialized to zero, for 5 subjects.
# >> Started estimator: GradientAscent
# ------------------------------------- Iteration: 0 -------------------------------------
# >> Log-likelihood = -4.522E+06 	 [ attachment = -4.522E+06 ; regularity = 0.000E+00 ]
# >> Step size and gradient norm:
# 		4.203E-06   and   2.379E+05 	[ landmark_points ]
# 		1.212E-05   and   8.253E+04 	[ momenta ]
# ------------------------------------- Iteration: 1 -------------------------------------
# >> Log-likelihood = -4.398E+06 	 [ attachment = -4.398E+06 ; regularity = -1.777E+00 ]
# >> Step size and gradient norm:
# 		6.304E-06   and   2.307E+05 	[ landmark_points ]
# 		1.818E-05   and   8.093E+04 	[ momenta ]
# ------------------------------------- Iteration: 2 -------------------------------------
# >> Log-likelihood = -4.221E+06 	 [ attachment = -4.221E+06 ; regularity = -1.084E+01 ]
# >> Step size and gradient norm:
# 		9.456E-06   and   2.199E+05 	[ landmark_points ]
# 		2.726E-05   and   7.857E+04 	[ momenta ]
# ------------------------------------- Iteration: 3 -------------------------------------
# >> Log-likelihood = -3.974E+06 	 [ attachment = -3.974E+06 ; regularity = -3.777E+01 ]
# >> Step size and gradient norm:
# 		1.418E-05   and   2.041E+05 	[ landmark_points ]
# 		4.090E-05   and   7.511E+04 	[ momenta ]
# ------------------------------------- Iteration: 4 -------------------------------------
# >> Log-likelihood = -3.645E+06 	 [ attachment = -3.645E+06 ; regularity = -1.047E+02 ]
# >> Step size and gradient norm:
# 		2.128E-05   and   1.818E+05 	[ landmark_points ]
# 		6.135E-05   and   7.012E+04 	[ momenta ]
# ------------------------------------- Iteration: 5 -------------------------------------
# >> Log-likelihood = -3.233E+06 	 [ attachment = -3.233E+06 ; regularity = -2.540E+02 ]
# >> Step size and gradient norm:
# 		3.191E-05   and   1.515E+05 	[ landmark_points ]
# 		9.202E-05   and   6.320E+04 	[ momenta ]
# ------------------------------------- Iteration: 6 -------------------------------------
# >> Log-likelihood = -2.760E+06 	 [ attachment = -2.759E+06 ; regularity = -5.569E+02 ]
# >> Step size and gradient norm:
# 		4.787E-05   and   1.141E+05 	[ landmark_points ]
# 		1.380E-04   and   5.417E+04 	[ momenta ]
# ------------------------------------- Iteration: 7 -------------------------------------
# >> Log-likelihood = -2.277E+06 	 [ attachment = -2.276E+06 ; regularity = -1.110E+03 ]
# >> Step size and gradient norm:
# 		7.181E-05   and   7.534E+04 	[ landmark_points ]
# 		2.070E-04   and   4.354E+04 	[ momenta ]
# ------------------------------------- Iteration: 8 -------------------------------------
# >> Log-likelihood = -1.849E+06 	 [ attachment = -1.847E+06 ; regularity = -1.991E+03 ]
# >> Step size and gradient norm:
# 		1.077E-04   and   4.547E+04 	[ landmark_points ]
# 		3.106E-04   and   3.248E+04 	[ momenta ]
# ------------------------------------- Iteration: 9 -------------------------------------
# >> Log-likelihood = -1.519E+06 	 [ attachment = -1.515E+06 ; regularity = -3.179E+03 ]
# >> Step size and gradient norm:
# 		1.616E-04   and   3.021E+04 	[ landmark_points ]
# 		4.658E-04   and   2.218E+04 	[ momenta ]
# ------------------------------------- Iteration: 10 -------------------------------------
# >> Log-likelihood = -1.288E+06 	 [ attachment = -1.284E+06 ; regularity = -4.459E+03 ]
# >> Step size and gradient norm:
# 		2.423E-04   and   2.484E+04 	[ landmark_points ]
# 		6.988E-04   and   1.551E+04 	[ momenta ]
# ------------------------------------- Iteration: 11 -------------------------------------
# >> Log-likelihood = -1.111E+06 	 [ attachment = -1.105E+06 ; regularity = -5.656E+03 ]
# >> Step size and gradient norm:
# 		3.635E-04   and   2.569E+04 	[ landmark_points ]
# 		1.048E-03   and   1.402E+04 	[ momenta ]
# ------------------------------------- Iteration: 12 -------------------------------------
# >> Log-likelihood = -1.086E+06 	 [ attachment = -1.078E+06 ; regularity = -7.439E+03 ]
# >> Step size and gradient norm:
# 		5.453E-04   and   6.041E+04 	[ landmark_points ]
# 		1.572E-03   and   2.828E+04 	[ momenta ]
# >> Step size and gradient norm:
# 		2.726E-04   and   6.041E+04 	[ landmark_points ]
# 		7.861E-04   and   2.828E+04 	[ momenta ]
# ------------------------------------- Iteration: 13 -------------------------------------
# >> Log-likelihood = -1.075E+06 	 [ attachment = -1.067E+06 ; regularity = -8.310E+03 ]
# >> Step size and gradient norm:
# 		1.363E-04   and   7.013E+04 	[ landmark_points ]
# 		7.861E-04   and   3.140E+04 	[ momenta ]
# ------------------------------------- Iteration: 14 -------------------------------------
# >> Log-likelihood = -9.752E+05 	 [ attachment = -9.667E+05 ; regularity = -8.487E+03 ]
# >> Step size and gradient norm:
# 		1.363E-04   and   4.971E+04 	[ landmark_points ]
# 		3.931E-04   and   2.976E+04 	[ momenta ]
# ------------------------------------- Iteration: 15 -------------------------------------
# >> Log-likelihood = -8.901E+05 	 [ attachment = -8.812E+05 ; regularity = -8.955E+03 ]
# >> Step size and gradient norm:
# 		2.045E-04   and   5.471E+04 	[ landmark_points ]
# 		5.896E-04   and   2.852E+04 	[ momenta ]
# >> Step size and gradient norm:
# 		1.022E-04   and   5.471E+04 	[ landmark_points ]
# 		2.948E-04   and   2.852E+04 	[ momenta ]
# ------------------------------------- Iteration: 16 -------------------------------------
# >> Log-likelihood = -7.909E+05 	 [ attachment = -7.818E+05 ; regularity = -9.135E+03 ]
# >> Step size and gradient norm:
# 		1.534E-04   and   4.776E+04 	[ landmark_points ]
# 		4.422E-04   and   2.246E+04 	[ momenta ]
# ------------------------------------- Iteration: 17 -------------------------------------
# >> Log-likelihood = -7.671E+05 	 [ attachment = -7.577E+05 ; regularity = -9.340E+03 ]
# >> Step size and gradient norm:
# 		1.534E-04   and   5.803E+04 	[ landmark_points ]
# 		2.211E-04   and   2.336E+04 	[ momenta ]
# ------------------------------------- Iteration: 18 -------------------------------------
# >> Log-likelihood = -7.034E+05 	 [ attachment = -6.939E+05 ; regularity = -9.546E+03 ]
# >> Step size and gradient norm:
# 		7.668E-05   and   3.331E+04 	[ landmark_points ]
# 		2.211E-04   and   1.588E+04 	[ momenta ]
# ------------------------------------- Iteration: 19 -------------------------------------
# >> Log-likelihood = -6.741E+05 	 [ attachment = -6.644E+05 ; regularity = -9.706E+03 ]
# >> Step size and gradient norm:
# 		1.150E-04   and   2.414E+04 	[ landmark_points ]
# 		3.316E-04   and   1.138E+04 	[ momenta ]
# ------------------------------------- Iteration: 20 -------------------------------------
# >> Log-likelihood = -6.660E+05 	 [ attachment = -6.560E+05 ; regularity = -9.971E+03 ]
# >> Step size and gradient norm:
# 		1.725E-04   and   3.384E+04 	[ landmark_points ]
# 		4.975E-04   and   1.518E+04 	[ momenta ]
# >> Step size and gradient norm:
# 		8.627E-05   and   3.384E+04 	[ landmark_points ]
# 		2.487E-04   and   1.518E+04 	[ momenta ]
# ------------------------------------- Iteration: 21 -------------------------------------
# >> Log-likelihood = -6.505E+05 	 [ attachment = -6.404E+05 ; regularity = -1.011E+04 ]
# >> Step size and gradient norm:
# 		1.294E-04   and   3.131E+04 	[ landmark_points ]
# 		3.731E-04   and   1.372E+04 	[ momenta ]
# ------------------------------------- Iteration: 22 -------------------------------------
# >> Log-likelihood = -6.421E+05 	 [ attachment = -6.319E+05 ; regularity = -1.023E+04 ]
# >> Step size and gradient norm:
# 		1.294E-04   and   3.353E+04 	[ landmark_points ]
# 		1.865E-04   and   1.334E+04 	[ momenta ]
# ------------------------------------- Iteration: 23 -------------------------------------
# >> Log-likelihood = -6.356E+05 	 [ attachment = -6.253E+05 ; regularity = -1.033E+04 ]
# >> Step size and gradient norm:
# 		1.941E-04   and   3.556E+04 	[ landmark_points ]
# 		2.798E-04   and   1.394E+04 	[ momenta ]
# ------------------------------------- Iteration: 24 -------------------------------------
# >> Log-likelihood = -6.332E+05 	 [ attachment = -6.226E+05 ; regularity = -1.052E+04 ]
# >> Step size and gradient norm:
# 		9.705E-05   and   3.805E+04 	[ landmark_points ]
# 		2.798E-04   and   1.643E+04 	[ momenta ]
# ------------------------------------- Iteration: 25 -------------------------------------
# >> Log-likelihood = -6.089E+05 	 [ attachment = -5.984E+05 ; regularity = -1.057E+04 ]
# >> Step size and gradient norm:
# 		9.705E-05   and   2.373E+04 	[ landmark_points ]
# 		1.399E-04   and   9.309E+03 	[ momenta ]
# ------------------------------------- Iteration: 26 -------------------------------------
# >> Log-likelihood = -5.985E+05 	 [ attachment = -5.878E+05 ; regularity = -1.065E+04 ]
# >> Step size and gradient norm:
# 		1.456E-04   and   1.376E+04 	[ landmark_points ]
# 		2.099E-04   and   7.023E+03 	[ momenta ]
# ------------------------------------- Iteration: 27 -------------------------------------
# >> Log-likelihood = -5.941E+05 	 [ attachment = -5.834E+05 ; regularity = -1.075E+04 ]
# >> Step size and gradient norm:
# 		2.184E-04   and   2.017E+04 	[ landmark_points ]
# 		3.148E-04   and   8.481E+03 	[ momenta ]
# ------------------------------------- Iteration: 28 -------------------------------------
# >> Log-likelihood = -5.930E+05 	 [ attachment = -5.821E+05 ; regularity = -1.093E+04 ]
# >> Step size and gradient norm:
# 		1.092E-04   and   2.777E+04 	[ landmark_points ]
# 		3.148E-04   and   1.185E+04 	[ momenta ]
# ------------------------------------- Iteration: 29 -------------------------------------
# >> Log-likelihood = -5.839E+05 	 [ attachment = -5.729E+05 ; regularity = -1.099E+04 ]
# >> Step size and gradient norm:
# 		1.092E-04   and   2.515E+04 	[ landmark_points ]
# 		1.574E-04   and   9.732E+03 	[ momenta ]
# ------------------------------------- Iteration: 30 -------------------------------------
# >> Log-likelihood = -5.760E+05 	 [ attachment = -5.649E+05 ; regularity = -1.108E+04 ]
# >> Step size and gradient norm:
# 		1.638E-04   and   2.125E+04 	[ landmark_points ]
# 		2.361E-04   and   8.761E+03 	[ momenta ]
# ------------------------------------- Iteration: 31 -------------------------------------
# >> Log-likelihood = -5.689E+05 	 [ attachment = -5.577E+05 ; regularity = -1.117E+04 ]
# >> Step size and gradient norm:
# 		8.188E-05   and   1.846E+04 	[ landmark_points ]
# 		2.361E-04   and   8.409E+03 	[ momenta ]
# ------------------------------------- Iteration: 32 -------------------------------------
# >> Log-likelihood = -5.613E+05 	 [ attachment = -5.501E+05 ; regularity = -1.129E+04 ]
# >> Step size and gradient norm:
# 		1.228E-04   and   1.691E+04 	[ landmark_points ]
# 		3.541E-04   and   7.730E+03 	[ momenta ]
# ------------------------------------- Iteration: 33 -------------------------------------
# >> Log-likelihood = -5.561E+05 	 [ attachment = -5.446E+05 ; regularity = -1.144E+04 ]
# >> Step size and gradient norm:
# 		6.141E-05   and   1.875E+04 	[ landmark_points ]
# 		3.541E-04   and   9.443E+03 	[ momenta ]
# ------------------------------------- Iteration: 34 -------------------------------------
# >> Log-likelihood = -5.529E+05 	 [ attachment = -5.413E+05 ; regularity = -1.162E+04 ]
# >> Step size and gradient norm:
# 		9.212E-05   and   2.346E+04 	[ landmark_points ]
# 		5.312E-04   and   1.157E+04 	[ momenta ]
# ------------------------------------- Iteration: 35 -------------------------------------
# >> Log-likelihood = -5.495E+05 	 [ attachment = -5.378E+05 ; regularity = -1.172E+04 ]
# >> Step size and gradient norm:
# 		9.212E-05   and   2.801E+04 	[ landmark_points ]
# 		2.656E-04   and   1.247E+04 	[ momenta ]
# ------------------------------------- Iteration: 36 -------------------------------------
# >> Log-likelihood = -5.471E+05 	 [ attachment = -5.353E+05 ; regularity = -1.187E+04 ]
# >> Step size and gradient norm:
# 		1.382E-04   and   3.180E+04 	[ landmark_points ]
# 		3.984E-04   and   1.381E+04 	[ momenta ]
# >> Step size and gradient norm:
# 		6.909E-05   and   3.180E+04 	[ landmark_points ]
# 		1.992E-04   and   1.381E+04 	[ momenta ]
# ------------------------------------- Iteration: 37 -------------------------------------
# >> Log-likelihood = -5.298E+05 	 [ attachment = -5.178E+05 ; regularity = -1.194E+04 ]
# >> Step size and gradient norm:
# 		1.036E-04   and   2.020E+04 	[ landmark_points ]
# 		2.988E-04   and   9.126E+03 	[ momenta ]
# ------------------------------------- Iteration: 38 -------------------------------------
# >> Log-likelihood = -5.292E+05 	 [ attachment = -5.171E+05 ; regularity = -1.210E+04 ]
# >> Step size and gradient norm:
# 		1.555E-04   and   2.833E+04 	[ landmark_points ]
# 		4.482E-04   and   1.202E+04 	[ momenta ]
# >> Step size and gradient norm:
# 		7.773E-05   and   2.833E+04 	[ landmark_points ]
# 		2.241E-04   and   1.202E+04 	[ momenta ]
# ------------------------------------- Iteration: 39 -------------------------------------
# >> Log-likelihood = -5.188E+05 	 [ attachment = -5.066E+05 ; regularity = -1.218E+04 ]
# >> Step size and gradient norm:
# 		1.166E-04   and   2.344E+04 	[ landmark_points ]
# 		3.362E-04   and   1.021E+04 	[ momenta ]
# ------------------------------------- Iteration: 40 -------------------------------------
# >> Log-likelihood = -5.124E+05 	 [ attachment = -5.001E+05 ; regularity = -1.237E+04 ]
# >> Step size and gradient norm:
# 		5.829E-05   and   2.366E+04 	[ landmark_points ]
# 		3.362E-04   and   1.148E+04 	[ momenta ]
# ------------------------------------- Iteration: 41 -------------------------------------
# >> Log-likelihood = -5.083E+05 	 [ attachment = -4.958E+05 ; regularity = -1.249E+04 ]
# >> Step size and gradient norm:
# 		8.744E-05   and   2.622E+04 	[ landmark_points ]
# 		5.042E-04   and   1.299E+04 	[ momenta ]
# ------------------------------------- Iteration: 42 -------------------------------------
# >> Log-likelihood = -5.011E+05 	 [ attachment = -4.885E+05 ; regularity = -1.263E+04 ]
# >> Step size and gradient norm:
# 		8.744E-05   and   2.812E+04 	[ landmark_points ]
# 		2.521E-04   and   1.257E+04 	[ momenta ]
# ------------------------------------- Iteration: 43 -------------------------------------
# >> Log-likelihood = -4.947E+05 	 [ attachment = -4.819E+05 ; regularity = -1.272E+04 ]
# >> Step size and gradient norm:
# 		1.312E-04   and   2.916E+04 	[ landmark_points ]
# 		3.782E-04   and   1.272E+04 	[ momenta ]
# >> Step size and gradient norm:
# 		6.558E-05   and   2.916E+04 	[ landmark_points ]
# 		1.891E-04   and   1.272E+04 	[ momenta ]
# ------------------------------------- Iteration: 44 -------------------------------------
# >> Log-likelihood = -4.770E+05 	 [ attachment = -4.642E+05 ; regularity = -1.282E+04 ]
# >> Step size and gradient norm:
# 		9.837E-05   and   1.613E+04 	[ landmark_points ]
# 		2.836E-04   and   7.651E+03 	[ momenta ]
# ------------------------------------- Iteration: 45 -------------------------------------
# >> Log-likelihood = -4.713E+05 	 [ attachment = -4.584E+05 ; regularity = -1.294E+04 ]
# >> Step size and gradient norm:
# 		1.476E-04   and   2.057E+04 	[ landmark_points ]
# 		4.255E-04   and   9.124E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		7.378E-05   and   2.057E+04 	[ landmark_points ]
# 		2.127E-04   and   9.124E+03 	[ momenta ]
# ------------------------------------- Iteration: 46 -------------------------------------
# >> Log-likelihood = -4.614E+05 	 [ attachment = -4.483E+05 ; regularity = -1.305E+04 ]
# >> Step size and gradient norm:
# 		1.107E-04   and   1.549E+04 	[ landmark_points ]
# 		3.191E-04   and   7.385E+03 	[ momenta ]
# ------------------------------------- Iteration: 47 -------------------------------------
# >> Log-likelihood = -4.573E+05 	 [ attachment = -4.441E+05 ; regularity = -1.319E+04 ]
# >> Step size and gradient norm:
# 		1.660E-04   and   2.358E+04 	[ landmark_points ]
# 		4.786E-04   and   1.009E+04 	[ momenta ]
# >> Step size and gradient norm:
# 		8.300E-05   and   2.358E+04 	[ landmark_points ]
# 		2.393E-04   and   1.009E+04 	[ momenta ]
# ------------------------------------- Iteration: 48 -------------------------------------
# >> Log-likelihood = -4.486E+05 	 [ attachment = -4.353E+05 ; regularity = -1.331E+04 ]
# >> Step size and gradient norm:
# 		1.245E-04   and   2.209E+04 	[ landmark_points ]
# 		3.590E-04   and   9.571E+03 	[ momenta ]
# ------------------------------------- Iteration: 49 -------------------------------------
# >> Log-likelihood = -4.434E+05 	 [ attachment = -4.299E+05 ; regularity = -1.346E+04 ]
# >> Step size and gradient norm:
# 		6.225E-05   and   2.502E+04 	[ landmark_points ]
# 		3.590E-04   and   1.189E+04 	[ momenta ]
# ------------------------------------- Iteration: 50 -------------------------------------
# >> Log-likelihood = -4.416E+05 	 [ attachment = -4.279E+05 ; regularity = -1.365E+04 ]
# >> Step size and gradient norm:
# 		9.338E-05   and   2.997E+04 	[ landmark_points ]
# 		5.385E-04   and   1.475E+04 	[ momenta ]
# ------------------------------------- Iteration: 51 -------------------------------------
# >> Log-likelihood = -4.389E+05 	 [ attachment = -4.252E+05 ; regularity = -1.373E+04 ]
# >> Step size and gradient norm:
# 		9.338E-05   and   3.737E+04 	[ landmark_points ]
# 		2.692E-04   and   1.556E+04 	[ momenta ]
# ------------------------------------- Iteration: 52 -------------------------------------
# >> Log-likelihood = -4.376E+05 	 [ attachment = -4.237E+05 ; regularity = -1.389E+04 ]
# >> Step size and gradient norm:
# 		1.401E-04   and   4.196E+04 	[ landmark_points ]
# 		4.038E-04   and   1.716E+04 	[ momenta ]
# >> Step size and gradient norm:
# 		7.003E-05   and   4.196E+04 	[ landmark_points ]
# 		2.019E-04   and   1.716E+04 	[ momenta ]
# ------------------------------------- Iteration: 53 -------------------------------------
# >> Log-likelihood = -4.110E+05 	 [ attachment = -3.971E+05 ; regularity = -1.393E+04 ]
# >> Step size and gradient norm:
# 		1.050E-04   and   2.721E+04 	[ landmark_points ]
# 		3.029E-04   and   1.089E+04 	[ momenta ]
# ------------------------------------- Iteration: 54 -------------------------------------
# >> Log-likelihood = -4.007E+05 	 [ attachment = -3.866E+05 ; regularity = -1.411E+04 ]
# >> Step size and gradient norm:
# 		5.252E-05   and   2.080E+04 	[ landmark_points ]
# 		3.029E-04   and   1.017E+04 	[ momenta ]
# ------------------------------------- Iteration: 55 -------------------------------------
# >> Log-likelihood = -3.920E+05 	 [ attachment = -3.778E+05 ; regularity = -1.421E+04 ]
# >> Step size and gradient norm:
# 		7.879E-05   and   1.988E+04 	[ landmark_points ]
# 		4.543E-04   and   9.594E+03 	[ momenta ]
# ------------------------------------- Iteration: 56 -------------------------------------
# >> Log-likelihood = -3.836E+05 	 [ attachment = -3.693E+05 ; regularity = -1.434E+04 ]
# >> Step size and gradient norm:
# 		7.879E-05   and   1.758E+04 	[ landmark_points ]
# 		2.272E-04   and   8.049E+03 	[ momenta ]
# ------------------------------------- Iteration: 57 -------------------------------------
# >> Log-likelihood = -3.764E+05 	 [ attachment = -3.620E+05 ; regularity = -1.441E+04 ]
# >> Step size and gradient norm:
# 		1.182E-04   and   1.680E+04 	[ landmark_points ]
# 		3.407E-04   and   7.256E+03 	[ momenta ]
# ------------------------------------- Iteration: 58 -------------------------------------
# >> Log-likelihood = -3.705E+05 	 [ attachment = -3.559E+05 ; regularity = -1.460E+04 ]
# >> Step size and gradient norm:
# 		5.909E-05   and   1.732E+04 	[ landmark_points ]
# 		3.407E-04   and   8.158E+03 	[ momenta ]
# ------------------------------------- Iteration: 59 -------------------------------------
# >> Log-likelihood = -3.653E+05 	 [ attachment = -3.506E+05 ; regularity = -1.471E+04 ]
# >> Step size and gradient norm:
# 		8.864E-05   and   2.089E+04 	[ landmark_points ]
# 		5.111E-04   and   9.410E+03 	[ momenta ]
# ------------------------------------- Iteration: 60 -------------------------------------
# >> Log-likelihood = -3.619E+05 	 [ attachment = -3.470E+05 ; regularity = -1.485E+04 ]
# >> Step size and gradient norm:
# 		8.864E-05   and   2.528E+04 	[ landmark_points ]
# 		2.556E-04   and   9.757E+03 	[ momenta ]
# ------------------------------------- Iteration: 61 -------------------------------------
# >> Log-likelihood = -3.599E+05 	 [ attachment = -3.450E+05 ; regularity = -1.492E+04 ]
# >> Step size and gradient norm:
# 		1.330E-04   and   3.353E+04 	[ landmark_points ]
# 		3.833E-04   and   1.092E+04 	[ momenta ]
# >> Step size and gradient norm:
# 		6.648E-05   and   3.353E+04 	[ landmark_points ]
# 		1.917E-04   and   1.092E+04 	[ momenta ]
# ------------------------------------- Iteration: 62 -------------------------------------
# >> Log-likelihood = -3.494E+05 	 [ attachment = -3.343E+05 ; regularity = -1.503E+04 ]
# >> Step size and gradient norm:
# 		9.971E-05   and   2.544E+04 	[ landmark_points ]
# 		2.875E-04   and   7.732E+03 	[ momenta ]
# ------------------------------------- Iteration: 63 -------------------------------------
# >> Log-likelihood = -3.425E+05 	 [ attachment = -3.274E+05 ; regularity = -1.511E+04 ]
# >> Step size and gradient norm:
# 		4.986E-05   and   1.992E+04 	[ landmark_points ]
# 		2.875E-04   and   7.144E+03 	[ momenta ]
# ------------------------------------- Iteration: 64 -------------------------------------
# >> Log-likelihood = -3.366E+05 	 [ attachment = -3.214E+05 ; regularity = -1.525E+04 ]
# >> Step size and gradient norm:
# 		7.479E-05   and   1.717E+04 	[ landmark_points ]
# 		4.313E-04   and   6.352E+03 	[ momenta ]
# ------------------------------------- Iteration: 65 -------------------------------------
# >> Log-likelihood = -3.328E+05 	 [ attachment = -3.175E+05 ; regularity = -1.532E+04 ]
# >> Step size and gradient norm:
# 		7.479E-05   and   2.011E+04 	[ landmark_points ]
# 		2.156E-04   and   6.043E+03 	[ momenta ]
# ------------------------------------- Iteration: 66 -------------------------------------
# >> Log-likelihood = -3.296E+05 	 [ attachment = -3.142E+05 ; regularity = -1.542E+04 ]
# >> Step size and gradient norm:
# 		1.122E-04   and   2.225E+04 	[ landmark_points ]
# 		3.234E-04   and   6.118E+03 	[ momenta ]
# ------------------------------------- Iteration: 67 -------------------------------------
# >> Log-likelihood = -3.259E+05 	 [ attachment = -3.104E+05 ; regularity = -1.551E+04 ]
# >> Step size and gradient norm:
# 		5.609E-05   and   2.362E+04 	[ landmark_points ]
# 		3.234E-04   and   6.783E+03 	[ momenta ]
# ------------------------------------- Iteration: 68 -------------------------------------
# >> Log-likelihood = -3.232E+05 	 [ attachment = -3.075E+05 ; regularity = -1.566E+04 ]
# >> Step size and gradient norm:
# 		8.413E-05   and   2.562E+04 	[ landmark_points ]
# 		4.852E-04   and   7.319E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		4.207E-05   and   2.562E+04 	[ landmark_points ]
# 		2.426E-04   and   7.319E+03 	[ momenta ]
# ------------------------------------- Iteration: 69 -------------------------------------
# >> Log-likelihood = -3.158E+05 	 [ attachment = -3.001E+05 ; regularity = -1.571E+04 ]
# >> Step size and gradient norm:
# 		6.310E-05   and   1.577E+04 	[ landmark_points ]
# 		3.639E-04   and   5.186E+03 	[ momenta ]
# ------------------------------------- Iteration: 70 -------------------------------------
# >> Log-likelihood = -3.141E+05 	 [ attachment = -2.982E+05 ; regularity = -1.585E+04 ]
# >> Step size and gradient norm:
# 		9.465E-05   and   2.140E+04 	[ landmark_points ]
# 		5.458E-04   and   6.447E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		4.733E-05   and   2.140E+04 	[ landmark_points ]
# 		2.729E-04   and   6.447E+03 	[ momenta ]
# ------------------------------------- Iteration: 71 -------------------------------------
# >> Log-likelihood = -3.095E+05 	 [ attachment = -2.936E+05 ; regularity = -1.592E+04 ]
# >> Step size and gradient norm:
# 		7.099E-05   and   1.812E+04 	[ landmark_points ]
# 		4.094E-04   and   5.616E+03 	[ momenta ]
# ------------------------------------- Iteration: 72 -------------------------------------
# >> Log-likelihood = -3.057E+05 	 [ attachment = -2.897E+05 ; regularity = -1.607E+04 ]
# >> Step size and gradient norm:
# 		3.549E-05   and   1.784E+04 	[ landmark_points ]
# 		4.094E-04   and   6.512E+03 	[ momenta ]
# ------------------------------------- Iteration: 73 -------------------------------------
# >> Log-likelihood = -3.048E+05 	 [ attachment = -2.887E+05 ; regularity = -1.617E+04 ]
# >> Step size and gradient norm:
# 		5.324E-05   and   2.092E+04 	[ landmark_points ]
# 		6.140E-04   and   8.053E+03 	[ momenta ]
# ------------------------------------- Iteration: 74 -------------------------------------
# >> Log-likelihood = -3.021E+05 	 [ attachment = -2.858E+05 ; regularity = -1.627E+04 ]
# >> Step size and gradient norm:
# 		5.324E-05   and   2.253E+04 	[ landmark_points ]
# 		3.070E-04   and   8.042E+03 	[ momenta ]
# ------------------------------------- Iteration: 75 -------------------------------------
# >> Log-likelihood = -2.998E+05 	 [ attachment = -2.835E+05 ; regularity = -1.633E+04 ]
# >> Step size and gradient norm:
# 		7.986E-05   and   2.537E+04 	[ landmark_points ]
# 		4.605E-04   and   8.305E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		3.993E-05   and   2.537E+04 	[ landmark_points ]
# 		2.303E-04   and   8.305E+03 	[ momenta ]
# ------------------------------------- Iteration: 76 -------------------------------------
# >> Log-likelihood = -2.924E+05 	 [ attachment = -2.760E+05 ; regularity = -1.641E+04 ]
# >> Step size and gradient norm:
# 		5.990E-05   and   1.407E+04 	[ landmark_points ]
# 		3.454E-04   and   5.071E+03 	[ momenta ]
# ------------------------------------- Iteration: 77 -------------------------------------
# >> Log-likelihood = -2.905E+05 	 [ attachment = -2.741E+05 ; regularity = -1.649E+04 ]
# >> Step size and gradient norm:
# 		8.984E-05   and   1.970E+04 	[ landmark_points ]
# 		5.181E-04   and   6.208E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		4.492E-05   and   1.970E+04 	[ landmark_points ]
# 		2.590E-04   and   6.208E+03 	[ momenta ]
# ------------------------------------- Iteration: 78 -------------------------------------
# >> Log-likelihood = -2.863E+05 	 [ attachment = -2.697E+05 ; regularity = -1.658E+04 ]
# >> Step size and gradient norm:
# 		6.738E-05   and   1.421E+04 	[ landmark_points ]
# 		3.886E-04   and   5.084E+03 	[ momenta ]
# ------------------------------------- Iteration: 79 -------------------------------------
# >> Log-likelihood = -2.832E+05 	 [ attachment = -2.665E+05 ; regularity = -1.666E+04 ]
# >> Step size and gradient norm:
# 		3.369E-05   and   1.515E+04 	[ landmark_points ]
# 		3.886E-04   and   5.711E+03 	[ momenta ]
# ------------------------------------- Iteration: 80 -------------------------------------
# >> Log-likelihood = -2.810E+05 	 [ attachment = -2.642E+05 ; regularity = -1.678E+04 ]
# >> Step size and gradient norm:
# 		5.054E-05   and   1.448E+04 	[ landmark_points ]
# 		5.829E-04   and   6.797E+03 	[ momenta ]
# ------------------------------------- Iteration: 81 -------------------------------------
# >> Log-likelihood = -2.774E+05 	 [ attachment = -2.605E+05 ; regularity = -1.685E+04 ]
# >> Step size and gradient norm:
# 		5.054E-05   and   1.643E+04 	[ landmark_points ]
# 		2.914E-04   and   6.264E+03 	[ momenta ]
# ------------------------------------- Iteration: 82 -------------------------------------
# >> Log-likelihood = -2.734E+05 	 [ attachment = -2.565E+05 ; regularity = -1.694E+04 ]
# >> Step size and gradient norm:
# 		7.581E-05   and   1.453E+04 	[ landmark_points ]
# 		4.371E-04   and   6.175E+03 	[ momenta ]
# ------------------------------------- Iteration: 83 -------------------------------------
# >> Log-likelihood = -2.707E+05 	 [ attachment = -2.537E+05 ; regularity = -1.699E+04 ]
# >> Step size and gradient norm:
# 		7.581E-05   and   1.878E+04 	[ landmark_points ]
# 		2.186E-04   and   5.577E+03 	[ momenta ]
# ------------------------------------- Iteration: 84 -------------------------------------
# >> Log-likelihood = -2.690E+05 	 [ attachment = -2.519E+05 ; regularity = -1.707E+04 ]
# >> Step size and gradient norm:
# 		1.137E-04   and   2.105E+04 	[ landmark_points ]
# 		3.279E-04   and   6.336E+03 	[ momenta ]
# ------------------------------------- Iteration: 85 -------------------------------------
# >> Log-likelihood = -2.667E+05 	 [ attachment = -2.496E+05 ; regularity = -1.713E+04 ]
# >> Step size and gradient norm:
# 		5.685E-05   and   2.559E+04 	[ landmark_points ]
# 		3.279E-04   and   7.119E+03 	[ momenta ]
# ------------------------------------- Iteration: 86 -------------------------------------
# >> Log-likelihood = -2.653E+05 	 [ attachment = -2.480E+05 ; regularity = -1.726E+04 ]
# >> Step size and gradient norm:
# 		8.528E-05   and   2.734E+04 	[ landmark_points ]
# 		4.918E-04   and   8.472E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		4.264E-05   and   2.734E+04 	[ landmark_points ]
# 		2.459E-04   and   8.472E+03 	[ momenta ]
# ------------------------------------- Iteration: 87 -------------------------------------
# >> Log-likelihood = -2.568E+05 	 [ attachment = -2.395E+05 ; regularity = -1.730E+04 ]
# >> Step size and gradient norm:
# 		6.396E-05   and   1.861E+04 	[ landmark_points ]
# 		3.688E-04   and   5.819E+03 	[ momenta ]
# Tolerance threshold met. Stopping the optimization process.
# >> Estimation took: 02 minutes and 02 seconds

# %% [markdown]
# ## EVALUATION

# %%
# load data
fixed_effects = model.fixed_effects
momenta__est = fixed_effects['momenta']

#calculate strength of momenta and return listDescription
list_of_momenta =  [[] for i in range(len(momenta__est[0]))]
for i, m in enumerate(momenta__est):
    for j in range(len(m)):
        list_of_momenta[j].append(abs(sqrt(m[j,0] ** 2 + m[j,1] ** 2)))

standard_deviation_momenta = [pd.DataFrame(i).describe()[0]['std'] for i in list_of_momenta]
listDescription = pd.DataFrame(standard_deviation_momenta).describe()
f.write("list of momenta standard deviation: \n")
for i in listDescription[0].keys():
    f.write(i + ": " + str(listDescription[0][i]) + "\n")
f.write("\n")

f.write("dynamic time warping distance between raw and reconstruct: \n")
sumOfD = 0
#calculate distance between raw and reconstruct
for i, momentum__est in enumerate(momenta__est):   
    path_to_target__raw = dataset_specifications['dataset_filenames'][i][0]['bike']
    target_id = dataset_specifications['subject_ids'][i]
    target_points__raw, _, target_connectivity__raw = dfca.io.DeformableObjectReader.read_file(path_to_target__raw, extract_connectivity=True)

    model.exponential.set_initial_momenta(torch.from_numpy(momentum__est).to(torch.float32))
    model.exponential.update()
    target_points__rec = model.exponential.get_template_points()['landmark_points'].detach().cpu().numpy()

    d = dtw_ndim.distance(target_points__raw, target_points__rec)
    sumOfD += d
    f.write(str(i+1) + ": " + str(d) + "\n")
f.write("average of distance: " + str(sumOfD/5) + "\n")
f.write("\n")
f.close()
print('finish')
# Out:
# finish

# %% [markdown]
# ## Convert text file with results to excel file

# %%
xlsx_file = os.path.join(data_path_results, 'results_parameter_testing.xlsx') 

with open(xlsx_file, "a+") as c:
    print("file created")
    
workbook = xlsxwriter.Workbook(xlsx_file)
worksheet = workbook.add_worksheet("results")
data = open(output_file, "r")
linelist = data.readlines()

listOfTableDescription  = [' ', 'parameter:', 'attachmentType:', 'kernelWidth:',
                            'deformationKernelWidth:', 'noiseStd:', 
                            'numberOfTimePoints:', 'templateName:', ' ', 
                            'list of momenta standard deviation:', 'count:', 'mean:', 
                            'std:', 'min:', '25%: ', '50%:','75%:', 'max:', ' ', 
                            'dynamic time warping distance between raw and reconstruct:',
                             '1:', '2:', '3:', '4:', '5:','average of distance:']

for i in range(len(listOfTableDescription)):
    worksheet.write_row(i, 0, [listOfTableDescription[i]])

col = 0
row = 0
for num in range (0, len(linelist)):
    line = linelist[num]
    if (line[0] == "#"):
        col += 1
        row = 0
        continue
    splitline = line.split("\t")
    writeLine = [splitline[0][splitline[0].find(":") + 1:]]
    row += 1
    worksheet.write_row(row, col, writeLine) 

workbook.close() 
print("file closed")
# Out:
# file created
# file closed
