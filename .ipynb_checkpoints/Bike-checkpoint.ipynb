# %% [markdown]
# # Shape analysis with Deformetrica
#
# Please use Python 3.8 (https://www.python.org/downloads/) and Jupyter Notebook (https://jupyter.org/install)

# %% [markdown]
# ## Requirements
#
# Please run the following cell before the first use of this notebook. Depending on the system, it may take a while. (Only need once.)

# %%
! xargs -n1 pip install < requirements.txt
# Out:
# Requirement already satisfied: numpy in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (1.21.1)
# Requirement already satisfied: matplotlib in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (3.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib) (8.3.1)
# Requirement already satisfied: numpy>=1.16 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib) (1.21.1)
# Requirement already satisfied: six in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Requirement already satisfied: deformetrica in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (4.3.0)
# Requirement already satisfied: vtk>=8.2.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from deformetrica) (9.0.3)
# Requirement already satisfied: psutil>=5.4.8 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from deformetrica) (5.8.0)
# Requirement already satisfied: pillow>=5.4.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from deformetrica) (8.3.1)
# Requirement already satisfied: scikit-learn>=0.20.3 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from deformetrica) (0.24.2)
# Requirement already satisfied: pykeops==1.4.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from deformetrica) (1.4.1)
# Requirement already satisfied: nibabel>=2.3.3 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from deformetrica) (3.2.1)
# Requirement already satisfied: matplotlib>=2.2.2 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from deformetrica) (3.4.2)
# Requirement already satisfied: torch==1.6 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from deformetrica) (1.6.0)
# Requirement already satisfied: torchvision==0.7 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from deformetrica) (0.7.0)
# Requirement already satisfied: PyQt5 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from deformetrica) (5.15.4)
# Requirement already satisfied: numpy>=1.16.2 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from deformetrica) (1.21.1)
# Requirement already satisfied: GPUtil in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from pykeops==1.4.1->deformetrica) (1.4.0)
# Requirement already satisfied: future in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from torch==1.6->deformetrica) (0.18.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib>=2.2.2->deformetrica) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib>=2.2.2->deformetrica) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib>=2.2.2->deformetrica) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib>=2.2.2->deformetrica) (0.10.0)
# Requirement already satisfied: six in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=2.2.2->deformetrica) (1.16.0)
# Requirement already satisfied: packaging>=14.3 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from nibabel>=2.3.3->deformetrica) (21.0)
# Requirement already satisfied: scipy>=0.19.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from scikit-learn>=0.20.3->deformetrica) (1.7.0)
# Requirement already satisfied: joblib>=0.11 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from scikit-learn>=0.20.3->deformetrica) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from scikit-learn>=0.20.3->deformetrica) (2.2.0)
# Requirement already satisfied: Twisted>=17.5.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from vtk>=8.2.0->deformetrica) (21.2.0)
# Requirement already satisfied: wslink>=0.1.3 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from vtk>=8.2.0->deformetrica) (0.2.0)
# Requirement already satisfied: autobahn>=17.7.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from vtk>=8.2.0->deformetrica) (21.3.1)
# Requirement already satisfied: hyperlink>=21.0.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from autobahn>=17.7.1->vtk>=8.2.0->deformetrica) (21.0.0)
# Requirement already satisfied: cryptography>=3.4.6 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from autobahn>=17.7.1->vtk>=8.2.0->deformetrica) (3.4.7)
# Requirement already satisfied: txaio>=21.2.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from autobahn>=17.7.1->vtk>=8.2.0->deformetrica) (21.2.1)
# Requirement already satisfied: cffi>=1.12 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from cryptography>=3.4.6->autobahn>=17.7.1->vtk>=8.2.0->deformetrica) (1.14.6)
# Requirement already satisfied: pycparser in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=3.4.6->autobahn>=17.7.1->vtk>=8.2.0->deformetrica) (2.20)
# Requirement already satisfied: idna>=2.5 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from hyperlink>=21.0.0->autobahn>=17.7.1->vtk>=8.2.0->deformetrica) (3.2)
# Requirement already satisfied: constantly>=15.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from Twisted>=17.5.0->vtk>=8.2.0->deformetrica) (15.1.0)
# Requirement already satisfied: incremental>=16.10.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from Twisted>=17.5.0->vtk>=8.2.0->deformetrica) (21.3.0)
# Requirement already satisfied: zope.interface>=4.4.2 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from Twisted>=17.5.0->vtk>=8.2.0->deformetrica) (5.4.0)
# Requirement already satisfied: attrs>=19.2.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from Twisted>=17.5.0->vtk>=8.2.0->deformetrica) (21.2.0)
# Requirement already satisfied: Automat>=0.8.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from Twisted>=17.5.0->vtk>=8.2.0->deformetrica) (20.2.0)
# Requirement already satisfied: setuptools in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from zope.interface>=4.4.2->Twisted>=17.5.0->vtk>=8.2.0->deformetrica) (52.0.0.post20210125)
# Requirement already satisfied: PyQt5-Qt5>=5.15 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from PyQt5->deformetrica) (5.15.2)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from PyQt5->deformetrica) (12.9.0)
# Requirement already satisfied: opencv-python in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (4.5.3.56)
# Requirement already satisfied: numpy>=1.17.3 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from opencv-python) (1.21.1)
# Requirement already satisfied: vtk in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (9.0.3)
# Requirement already satisfied: Twisted>=17.5.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from vtk) (21.2.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from vtk) (3.4.2)
# Requirement already satisfied: wslink>=0.1.3 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from vtk) (0.2.0)
# Requirement already satisfied: autobahn>=17.7.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from vtk) (21.3.1)
# Requirement already satisfied: hyperlink>=21.0.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from autobahn>=17.7.1->vtk) (21.0.0)
# Requirement already satisfied: cryptography>=3.4.6 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from autobahn>=17.7.1->vtk) (3.4.7)
# Requirement already satisfied: txaio>=21.2.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from autobahn>=17.7.1->vtk) (21.2.1)
# Requirement already satisfied: cffi>=1.12 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from cryptography>=3.4.6->autobahn>=17.7.1->vtk) (1.14.6)
# Requirement already satisfied: pycparser in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=3.4.6->autobahn>=17.7.1->vtk) (2.20)
# Requirement already satisfied: idna>=2.5 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from hyperlink>=21.0.0->autobahn>=17.7.1->vtk) (3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib>=2.0.0->vtk) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib>=2.0.0->vtk) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib>=2.0.0->vtk) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib>=2.0.0->vtk) (8.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib>=2.0.0->vtk) (2.4.7)
# Requirement already satisfied: numpy>=1.16 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib>=2.0.0->vtk) (1.21.1)
# Requirement already satisfied: six in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=2.0.0->vtk) (1.16.0)
# Requirement already satisfied: constantly>=15.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from Twisted>=17.5.0->vtk) (15.1.0)
# Requirement already satisfied: Automat>=0.8.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from Twisted>=17.5.0->vtk) (20.2.0)
# Requirement already satisfied: zope.interface>=4.4.2 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from Twisted>=17.5.0->vtk) (5.4.0)
# Requirement already satisfied: incremental>=16.10.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from Twisted>=17.5.0->vtk) (21.3.0)
# Requirement already satisfied: attrs>=19.2.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from Twisted>=17.5.0->vtk) (21.2.0)
# Requirement already satisfied: setuptools in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from zope.interface>=4.4.2->Twisted>=17.5.0->vtk) (52.0.0.post20210125)
# Requirement already satisfied: mayavi in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (4.7.3)
# Requirement already satisfied: traits>=6.0.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from mayavi) (6.2.0)
# Requirement already satisfied: envisage in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from mayavi) (6.0.1)
# Requirement already satisfied: numpy in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from mayavi) (1.21.1)
# Requirement already satisfied: traitsui>=7.0.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from mayavi) (7.2.1)
# Requirement already satisfied: vtk in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from mayavi) (9.0.3)
# Requirement already satisfied: pyface>=6.1.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from mayavi) (7.3.0)
# Requirement already satisfied: pygments in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from mayavi) (2.9.0)
# Requirement already satisfied: apptools in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from mayavi) (5.1.0)
# Requirement already satisfied: importlib-metadata in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from pyface>=6.1.1->mayavi) (4.6.1)
# Requirement already satisfied: importlib-resources>=1.1.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from pyface>=6.1.1->mayavi) (5.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from importlib-resources>=1.1.0->pyface>=6.1.1->mayavi) (3.5.0)
# Requirement already satisfied: configobj in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from apptools->mayavi) (5.0.6)
# Requirement already satisfied: six in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from configobj->apptools->mayavi) (1.16.0)
# Requirement already satisfied: setuptools in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from envisage->mayavi) (52.0.0.post20210125)
# Requirement already satisfied: Twisted>=17.5.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from vtk->mayavi) (21.2.0)
# Requirement already satisfied: wslink>=0.1.3 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from vtk->mayavi) (0.2.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from vtk->mayavi) (3.4.2)
# Requirement already satisfied: autobahn>=17.7.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from vtk->mayavi) (21.3.1)
# Requirement already satisfied: hyperlink>=21.0.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from autobahn>=17.7.1->vtk->mayavi) (21.0.0)
# Requirement already satisfied: cryptography>=3.4.6 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from autobahn>=17.7.1->vtk->mayavi) (3.4.7)
# Requirement already satisfied: txaio>=21.2.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from autobahn>=17.7.1->vtk->mayavi) (21.2.1)
# Requirement already satisfied: cffi>=1.12 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from cryptography>=3.4.6->autobahn>=17.7.1->vtk->mayavi) (1.14.6)
# Requirement already satisfied: pycparser in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=3.4.6->autobahn>=17.7.1->vtk->mayavi) (2.20)
# Requirement already satisfied: idna>=2.5 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from hyperlink>=21.0.0->autobahn>=17.7.1->vtk->mayavi) (3.2)
# Requirement already satisfied: cycler>=0.10 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib>=2.0.0->vtk->mayavi) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib>=2.0.0->vtk->mayavi) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib>=2.0.0->vtk->mayavi) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib>=2.0.0->vtk->mayavi) (8.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from matplotlib>=2.0.0->vtk->mayavi) (1.3.1)
# Requirement already satisfied: zope.interface>=4.4.2 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from Twisted>=17.5.0->vtk->mayavi) (5.4.0)
# Requirement already satisfied: attrs>=19.2.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from Twisted>=17.5.0->vtk->mayavi) (21.2.0)
# Requirement already satisfied: incremental>=16.10.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from Twisted>=17.5.0->vtk->mayavi) (21.3.0)
# Requirement already satisfied: constantly>=15.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from Twisted>=17.5.0->vtk->mayavi) (15.1.0)
# Requirement already satisfied: Automat>=0.8.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from Twisted>=17.5.0->vtk->mayavi) (20.2.0)
# Requirement already satisfied: shapely in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (1.7.1)
# Requirement already satisfied: pandas in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (1.3.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.17.3 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from pandas) (1.21.1)
# Requirement already satisfied: six>=1.5 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: torchvision in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (0.7.0)
# Requirement already satisfied: torch==1.6.0 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from torchvision) (1.6.0)
# Requirement already satisfied: pillow>=4.1.1 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from torchvision) (8.3.1)
# Requirement already satisfied: numpy in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from torchvision) (1.21.1)
# Requirement already satisfied: future in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from torch==1.6.0->torchvision) (0.18.2)
# Requirement already satisfied: Cython in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (0.29.24)
# Requirement already satisfied: dtaidistance in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (2.3.1)
# Requirement already satisfied: cython>=0.29.6 in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (from dtaidistance) (0.29.24)
# Requirement already satisfied: xlsxwriter in /home/ahmet/miniconda3/envs/test/lib/python3.8/site-packages (1.4.4)

# %% [markdown]
# ## Preparation
#
# The PNG files can prepare with the following cell. If you want to use your own data, you have to replace the files in "images/mask_png".

# %%
#convert png to vtk
# %run png_to_vtk.ipynb
#create own controlpoints 
# %run create_own_controlpoints.ipynb
# Out:
# vtks created succesfully
# control points created succesfully

# %% [markdown]
# ## Plot data

# %%
import os
import glob
import re
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import deformetrica as dfca
import logging
logging.getLogger('matplotlib').setLevel(logging.ERROR)
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

data_path = "images/"
data_base = os.path.join(data_path, 'mask_vtk/')
vtk_files = glob.glob(data_base + "*.vtk")

figsize = 5
f = plt.figure(figsize=(10 * figsize, 1 * figsize))
gs = gridspec.GridSpec(1, len(vtk_files))

for i, vtk_file in enumerate(vtk_files):
    ax = plt.subplot(gs[0, i])
    
    m = re.findall(r".*\/(.*)\..*", vtk_file)
    target_id = m[0]
    target_points__raw, _, target_connectivity__raw = dfca.io.DeformableObjectReader.read_file(vtk_file, extract_connectivity=True)

    p = target_points__raw
    c = target_connectivity__raw
    
    ax.plot([p[c[:, 0]][:, 0], p[c[:, 1]][:, 0]], [p[c[:, 0]][:, 1], p[c[:, 1]][:, 1]], 'k', linewidth=2)
    ax.invert_yaxis();
    ax.set_title(target_id)

plt.style.use('default')
plt.show()

# %% [markdown]
# ## Run Deformetrica

# %%
import os
import deformetrica as dfca

data_path = "images/"
data_base = os.path.join(data_path, 'mask_vtk/')
data_base_control_points = os.path.join(data_path, 'mask_initial_control_points/')

iteration_status_dictionaries = []
def estimator_callback(status_dict):
    iteration_status_dictionaries.append(status_dict)
    return True

# instantiate a Deformetrica object
deformetrica = dfca.Deformetrica(output_dir='output', verbosity='INFO')

dataset_specifications = {
    'dataset_filenames': [
        [{'bike': os.path.join(data_base, 'mask_01.vtk')}],
        [{'bike': os.path.join(data_base, 'mask_02.vtk')}],
        [{'bike': os.path.join(data_base, 'mask_03.vtk')}],
        [{'bike': os.path.join(data_base, 'mask_04.vtk')}],
        [{'bike': os.path.join(data_base, 'mask_05.vtk')}]],
    'subject_ids': ['mask_01', 'mask_02', 'mask_03', 'mask_04', 'mask_05'],
}
template_specifications = {
    'bike': {'deformable_object_type': 'polyline',
              'kernel_type': 'torch', 'kernel_width': 10,
              'noise_std': 0.25,
              'filename': os.path.join(data_base, 'mask_03.vtk'),
              'attachment_type': 'varifold'}
}
estimator_options={'optimization_method_type': 'GradientAscent', 'initial_step_size': 1.,
                               'max_iterations': 100, 'max_line_search_iterations': 10, 'callback': estimator_callback}

# perform a deterministic atlas estimation
model = deformetrica.estimate_deterministic_atlas(template_specifications, dataset_specifications,
                                                estimator_options=estimator_options,
                                                model_options={'deformation_kernel_type': 'torch', 'deformation_kernel_width': 10.0, 
                                                                           'dtype': 'float32', 'number_of_time_points': 11, 
                                                                           'initial_control_points': os.path.join(data_base_control_points, 'mask_03_initial_control_points.txt')})
# Out:
# Logger has been set to: INFO
# OMP_NUM_THREADS was not found in environment variables. An automatic value will be set.
# OMP_NUM_THREADS will be set to 2
# >> No specified state-file. By default, Deformetrica state will by saved in file: output/deformetrica-state.p.
# >> Removing the pre-existing state file with same path.
# >> Reading 200 initial control points from file images/mask_initial_control_points/mask_03_initial_control_points.txt.
# >> Momenta initialized to zero, for 5 subjects.
# >> Started estimator: GradientAscent
# ------------------------------------- Iteration: 0 -------------------------------------
# >> Log-likelihood = -7.236E+05 	 [ attachment = -7.236E+05 ; regularity = 0.000E+00 ]
# >> Step size and gradient norm:
# 		2.627E-05   and   3.807E+04 	[ landmark_points ]
# 		7.573E-05   and   1.320E+04 	[ momenta ]
# ------------------------------------- Iteration: 1 -------------------------------------
# >> Log-likelihood = -7.036E+05 	 [ attachment = -7.036E+05 ; regularity = -1.777E+00 ]
# >> Step size and gradient norm:
# 		3.940E-05   and   3.690E+04 	[ landmark_points ]
# 		1.136E-04   and   1.295E+04 	[ momenta ]
# ------------------------------------- Iteration: 2 -------------------------------------
# >> Log-likelihood = -6.753E+05 	 [ attachment = -6.753E+05 ; regularity = -1.084E+01 ]
# >> Step size and gradient norm:
# 		5.910E-05   and   3.518E+04 	[ landmark_points ]
# 		1.704E-04   and   1.256E+04 	[ momenta ]
# ------------------------------------- Iteration: 3 -------------------------------------
# >> Log-likelihood = -6.359E+05 	 [ attachment = -6.358E+05 ; regularity = -3.774E+01 ]
# >> Step size and gradient norm:
# 		8.865E-05   and   3.266E+04 	[ landmark_points ]
# 		2.556E-04   and   1.200E+04 	[ momenta ]
# ------------------------------------- Iteration: 4 -------------------------------------
# >> Log-likelihood = -5.834E+05 	 [ attachment = -5.833E+05 ; regularity = -1.045E+02 ]
# >> Step size and gradient norm:
# 		1.330E-04   and   2.909E+04 	[ landmark_points ]
# 		3.834E-04   and   1.120E+04 	[ momenta ]
# ------------------------------------- Iteration: 5 -------------------------------------
# >> Log-likelihood = -5.177E+05 	 [ attachment = -5.174E+05 ; regularity = -2.534E+02 ]
# >> Step size and gradient norm:
# 		1.995E-04   and   2.424E+04 	[ landmark_points ]
# 		5.751E-04   and   1.008E+04 	[ momenta ]
# ------------------------------------- Iteration: 6 -------------------------------------
# >> Log-likelihood = -4.423E+05 	 [ attachment = -4.418E+05 ; regularity = -5.548E+02 ]
# >> Step size and gradient norm:
# 		2.992E-04   and   1.827E+04 	[ landmark_points ]
# 		8.627E-04   and   8.623E+03 	[ momenta ]
# ------------------------------------- Iteration: 7 -------------------------------------
# >> Log-likelihood = -3.657E+05 	 [ attachment = -3.646E+05 ; regularity = -1.103E+03 ]
# >> Step size and gradient norm:
# 		4.488E-04   and   1.208E+04 	[ landmark_points ]
# 		1.294E-03   and   6.910E+03 	[ momenta ]
# ------------------------------------- Iteration: 8 -------------------------------------
# >> Log-likelihood = -2.980E+05 	 [ attachment = -2.961E+05 ; regularity = -1.974E+03 ]
# >> Step size and gradient norm:
# 		6.732E-04   and   7.303E+03 	[ landmark_points ]
# 		1.941E-03   and   5.137E+03 	[ momenta ]
# ------------------------------------- Iteration: 9 -------------------------------------
# >> Log-likelihood = -2.463E+05 	 [ attachment = -2.432E+05 ; regularity = -3.137E+03 ]
# >> Step size and gradient norm:
# 		1.010E-03   and   4.836E+03 	[ landmark_points ]
# 		2.911E-03   and   3.491E+03 	[ momenta ]
# ------------------------------------- Iteration: 10 -------------------------------------
# >> Log-likelihood = -2.105E+05 	 [ attachment = -2.061E+05 ; regularity = -4.376E+03 ]
# >> Step size and gradient norm:
# 		1.515E-03   and   3.974E+03 	[ landmark_points ]
# 		4.367E-03   and   2.425E+03 	[ momenta ]
# ------------------------------------- Iteration: 11 -------------------------------------
# >> Log-likelihood = -1.832E+05 	 [ attachment = -1.776E+05 ; regularity = -5.512E+03 ]
# >> Step size and gradient norm:
# 		2.272E-03   and   4.067E+03 	[ landmark_points ]
# 		6.551E-03   and   2.179E+03 	[ momenta ]
# ------------------------------------- Iteration: 12 -------------------------------------
# >> Log-likelihood = -1.804E+05 	 [ attachment = -1.732E+05 ; regularity = -7.184E+03 ]
# >> Step size and gradient norm:
# 		3.408E-03   and   9.638E+03 	[ landmark_points ]
# 		9.826E-03   and   4.515E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		1.704E-03   and   9.638E+03 	[ landmark_points ]
# 		4.913E-03   and   4.515E+03 	[ momenta ]
# ------------------------------------- Iteration: 13 -------------------------------------
# >> Log-likelihood = -1.803E+05 	 [ attachment = -1.723E+05 ; regularity = -7.947E+03 ]
# >> Step size and gradient norm:
# 		8.520E-04   and   1.095E+04 	[ landmark_points ]
# 		4.913E-03   and   4.995E+03 	[ momenta ]
# ------------------------------------- Iteration: 14 -------------------------------------
# >> Log-likelihood = -1.641E+05 	 [ attachment = -1.560E+05 ; regularity = -8.102E+03 ]
# >> Step size and gradient norm:
# 		8.520E-04   and   7.677E+03 	[ landmark_points ]
# 		2.457E-03   and   4.658E+03 	[ momenta ]
# ------------------------------------- Iteration: 15 -------------------------------------
# >> Log-likelihood = -1.503E+05 	 [ attachment = -1.418E+05 ; regularity = -8.538E+03 ]
# >> Step size and gradient norm:
# 		1.278E-03   and   7.858E+03 	[ landmark_points ]
# 		3.685E-03   and   4.284E+03 	[ momenta ]
# ------------------------------------- Iteration: 16 -------------------------------------
# >> Log-likelihood = -1.484E+05 	 [ attachment = -1.397E+05 ; regularity = -8.691E+03 ]
# >> Step size and gradient norm:
# 		1.278E-03   and   1.114E+04 	[ landmark_points ]
# 		1.842E-03   and   4.329E+03 	[ momenta ]
# ------------------------------------- Iteration: 17 -------------------------------------
# >> Log-likelihood = -1.304E+05 	 [ attachment = -1.214E+05 ; regularity = -9.024E+03 ]
# >> Step size and gradient norm:
# 		6.390E-04   and   7.976E+03 	[ landmark_points ]
# 		1.842E-03   and   3.535E+03 	[ momenta ]
# ------------------------------------- Iteration: 18 -------------------------------------
# >> Log-likelihood = -1.258E+05 	 [ attachment = -1.166E+05 ; regularity = -9.167E+03 ]
# >> Step size and gradient norm:
# 		9.585E-04   and   8.171E+03 	[ landmark_points ]
# 		2.764E-03   and   3.270E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		4.793E-04   and   8.171E+03 	[ landmark_points ]
# 		1.382E-03   and   3.270E+03 	[ momenta ]
# ------------------------------------- Iteration: 19 -------------------------------------
# >> Log-likelihood = -1.169E+05 	 [ attachment = -1.075E+05 ; regularity = -9.346E+03 ]
# >> Step size and gradient norm:
# 		7.189E-04   and   4.481E+03 	[ landmark_points ]
# 		2.073E-03   and   2.038E+03 	[ momenta ]
# ------------------------------------- Iteration: 20 -------------------------------------
# >> Log-likelihood = -1.164E+05 	 [ attachment = -1.069E+05 ; regularity = -9.509E+03 ]
# >> Step size and gradient norm:
# 		1.078E-03   and   6.279E+03 	[ landmark_points ]
# 		3.109E-03   and   2.589E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		5.392E-04   and   6.279E+03 	[ landmark_points ]
# 		1.555E-03   and   2.589E+03 	[ momenta ]
# ------------------------------------- Iteration: 21 -------------------------------------
# >> Log-likelihood = -1.133E+05 	 [ attachment = -1.036E+05 ; regularity = -9.673E+03 ]
# >> Step size and gradient norm:
# 		8.087E-04   and   5.199E+03 	[ landmark_points ]
# 		2.332E-03   and   2.291E+03 	[ momenta ]
# ------------------------------------- Iteration: 22 -------------------------------------
# >> Log-likelihood = -1.125E+05 	 [ attachment = -1.028E+05 ; regularity = -9.732E+03 ]
# >> Step size and gradient norm:
# 		8.087E-04   and   6.014E+03 	[ landmark_points ]
# 		1.166E-03   and   2.213E+03 	[ momenta ]
# ------------------------------------- Iteration: 23 -------------------------------------
# >> Log-likelihood = -1.124E+05 	 [ attachment = -1.025E+05 ; regularity = -9.847E+03 ]
# >> Step size and gradient norm:
# 		1.213E-03   and   6.371E+03 	[ landmark_points ]
# 		1.749E-03   and   2.615E+03 	[ momenta ]
# ------------------------------------- Iteration: 24 -------------------------------------
# >> Log-likelihood = -1.121E+05 	 [ attachment = -1.021E+05 ; regularity = -9.934E+03 ]
# >> Step size and gradient norm:
# 		6.066E-04   and   6.827E+03 	[ landmark_points ]
# 		1.749E-03   and   2.840E+03 	[ momenta ]
# ------------------------------------- Iteration: 25 -------------------------------------
# >> Log-likelihood = -1.120E+05 	 [ attachment = -1.019E+05 ; regularity = -1.007E+04 ]
# >> Step size and gradient norm:
# 		9.098E-04   and   7.257E+03 	[ landmark_points ]
# 		2.623E-03   and   3.165E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		4.549E-04   and   7.257E+03 	[ landmark_points ]
# 		1.312E-03   and   3.165E+03 	[ momenta ]
# ------------------------------------- Iteration: 26 -------------------------------------
# >> Log-likelihood = -1.065E+05 	 [ attachment = -9.636E+04 ; regularity = -1.012E+04 ]
# >> Step size and gradient norm:
# 		6.824E-04   and   4.379E+03 	[ landmark_points ]
# 		1.967E-03   and   1.920E+03 	[ momenta ]
# ------------------------------------- Iteration: 27 -------------------------------------
# >> Log-likelihood = -1.046E+05 	 [ attachment = -9.447E+04 ; regularity = -1.018E+04 ]
# >> Step size and gradient norm:
# 		6.824E-04   and   3.565E+03 	[ landmark_points ]
# 		9.837E-04   and   1.508E+03 	[ momenta ]
# ------------------------------------- Iteration: 28 -------------------------------------
# >> Log-likelihood = -1.033E+05 	 [ attachment = -9.306E+04 ; regularity = -1.024E+04 ]
# >> Step size and gradient norm:
# 		1.024E-03   and   2.865E+03 	[ landmark_points ]
# 		1.476E-03   and   1.264E+03 	[ momenta ]
# ------------------------------------- Iteration: 29 -------------------------------------
# >> Log-likelihood = -1.022E+05 	 [ attachment = -9.190E+04 ; regularity = -1.033E+04 ]
# >> Step size and gradient norm:
# 		5.118E-04   and   2.419E+03 	[ landmark_points ]
# 		1.476E-03   and   1.182E+03 	[ momenta ]
# ------------------------------------- Iteration: 30 -------------------------------------
# >> Log-likelihood = -1.012E+05 	 [ attachment = -9.081E+04 ; regularity = -1.040E+04 ]
# >> Step size and gradient norm:
# 		7.677E-04   and   2.225E+03 	[ landmark_points ]
# 		2.213E-03   and   1.053E+03 	[ momenta ]
# ------------------------------------- Iteration: 31 -------------------------------------
# >> Log-likelihood = -1.012E+05 	 [ attachment = -9.062E+04 ; regularity = -1.054E+04 ]
# >> Step size and gradient norm:
# 		1.152E-03   and   3.718E+03 	[ landmark_points ]
# 		3.320E-03   and   1.704E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		5.758E-04   and   3.718E+03 	[ landmark_points ]
# 		1.660E-03   and   1.704E+03 	[ momenta ]
# ------------------------------------- Iteration: 32 -------------------------------------
# >> Log-likelihood = -1.006E+05 	 [ attachment = -9.002E+04 ; regularity = -1.062E+04 ]
# >> Step size and gradient norm:
# 		8.636E-04   and   4.237E+03 	[ landmark_points ]
# 		2.490E-03   and   1.808E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		4.318E-04   and   4.237E+03 	[ landmark_points ]
# 		1.245E-03   and   1.808E+03 	[ momenta ]
# ------------------------------------- Iteration: 33 -------------------------------------
# >> Log-likelihood = -9.856E+04 	 [ attachment = -8.787E+04 ; regularity = -1.069E+04 ]
# >> Step size and gradient norm:
# 		6.477E-04   and   2.531E+03 	[ landmark_points ]
# 		1.868E-03   and   1.209E+03 	[ momenta ]
# ------------------------------------- Iteration: 34 -------------------------------------
# >> Log-likelihood = -9.823E+04 	 [ attachment = -8.744E+04 ; regularity = -1.078E+04 ]
# >> Step size and gradient norm:
# 		9.716E-04   and   3.551E+03 	[ landmark_points ]
# 		2.801E-03   and   1.514E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		4.858E-04   and   3.551E+03 	[ landmark_points ]
# 		1.401E-03   and   1.514E+03 	[ momenta ]
# ------------------------------------- Iteration: 35 -------------------------------------
# >> Log-likelihood = -9.689E+04 	 [ attachment = -8.603E+04 ; regularity = -1.086E+04 ]
# >> Step size and gradient norm:
# 		7.287E-04   and   2.812E+03 	[ landmark_points ]
# 		2.101E-03   and   1.309E+03 	[ momenta ]
# ------------------------------------- Iteration: 36 -------------------------------------
# >> Log-likelihood = -9.604E+04 	 [ attachment = -8.507E+04 ; regularity = -1.097E+04 ]
# >> Step size and gradient norm:
# 		3.643E-04   and   2.976E+03 	[ landmark_points ]
# 		2.101E-03   and   1.422E+03 	[ momenta ]
# ------------------------------------- Iteration: 37 -------------------------------------
# >> Log-likelihood = -9.528E+04 	 [ attachment = -8.419E+04 ; regularity = -1.109E+04 ]
# >> Step size and gradient norm:
# 		5.465E-04   and   3.139E+03 	[ landmark_points ]
# 		3.152E-03   and   1.599E+03 	[ momenta ]
# ------------------------------------- Iteration: 38 -------------------------------------
# >> Log-likelihood = -9.430E+04 	 [ attachment = -8.313E+04 ; regularity = -1.117E+04 ]
# >> Step size and gradient norm:
# 		5.465E-04   and   3.456E+03 	[ landmark_points ]
# 		1.576E-03   and   1.524E+03 	[ momenta ]
# ------------------------------------- Iteration: 39 -------------------------------------
# >> Log-likelihood = -9.348E+04 	 [ attachment = -8.222E+04 ; regularity = -1.126E+04 ]
# >> Step size and gradient norm:
# 		8.198E-04   and   3.437E+03 	[ landmark_points ]
# 		2.364E-03   and   1.587E+03 	[ momenta ]
# ------------------------------------- Iteration: 40 -------------------------------------
# >> Log-likelihood = -9.315E+04 	 [ attachment = -8.182E+04 ; regularity = -1.133E+04 ]
# >> Step size and gradient norm:
# 		8.198E-04   and   4.587E+03 	[ landmark_points ]
# 		1.182E-03   and   1.711E+03 	[ momenta ]
# ------------------------------------- Iteration: 41 -------------------------------------
# >> Log-likelihood = -9.089E+04 	 [ attachment = -7.949E+04 ; regularity = -1.140E+04 ]
# >> Step size and gradient norm:
# 		4.099E-04   and   2.402E+03 	[ landmark_points ]
# 		1.182E-03   and   1.176E+03 	[ momenta ]
# ------------------------------------- Iteration: 42 -------------------------------------
# >> Log-likelihood = -8.967E+04 	 [ attachment = -7.820E+04 ; regularity = -1.146E+04 ]
# >> Step size and gradient norm:
# 		6.148E-04   and   1.693E+03 	[ landmark_points ]
# 		1.773E-03   and   8.433E+02 	[ momenta ]
# ------------------------------------- Iteration: 43 -------------------------------------
# >> Log-likelihood = -8.851E+04 	 [ attachment = -7.694E+04 ; regularity = -1.158E+04 ]
# >> Step size and gradient norm:
# 		9.222E-04   and   1.943E+03 	[ landmark_points ]
# 		2.659E-03   and   9.842E+02 	[ momenta ]
# ------------------------------------- Iteration: 44 -------------------------------------
# >> Log-likelihood = -8.817E+04 	 [ attachment = -7.644E+04 ; regularity = -1.173E+04 ]
# >> Step size and gradient norm:
# 		1.383E-03   and   4.377E+03 	[ landmark_points ]
# 		3.989E-03   and   1.688E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		6.917E-04   and   4.377E+03 	[ landmark_points ]
# 		1.994E-03   and   1.688E+03 	[ momenta ]
# ------------------------------------- Iteration: 45 -------------------------------------
# >> Log-likelihood = -8.678E+04 	 [ attachment = -7.490E+04 ; regularity = -1.188E+04 ]
# >> Step size and gradient norm:
# 		3.458E-04   and   3.729E+03 	[ landmark_points ]
# 		1.994E-03   and   1.752E+03 	[ momenta ]
# ------------------------------------- Iteration: 46 -------------------------------------
# >> Log-likelihood = -8.543E+04 	 [ attachment = -7.346E+04 ; regularity = -1.197E+04 ]
# >> Step size and gradient norm:
# 		5.188E-04   and   3.786E+03 	[ landmark_points ]
# 		2.991E-03   and   1.714E+03 	[ momenta ]
# ------------------------------------- Iteration: 47 -------------------------------------
# >> Log-likelihood = -8.398E+04 	 [ attachment = -7.190E+04 ; regularity = -1.208E+04 ]
# >> Step size and gradient norm:
# 		5.188E-04   and   3.635E+03 	[ landmark_points ]
# 		1.496E-03   and   1.581E+03 	[ momenta ]
# ------------------------------------- Iteration: 48 -------------------------------------
# >> Log-likelihood = -8.259E+04 	 [ attachment = -7.043E+04 ; regularity = -1.216E+04 ]
# >> Step size and gradient norm:
# 		7.781E-04   and   3.458E+03 	[ landmark_points ]
# 		2.244E-03   and   1.447E+03 	[ momenta ]
# ------------------------------------- Iteration: 49 -------------------------------------
# >> Log-likelihood = -8.178E+04 	 [ attachment = -6.946E+04 ; regularity = -1.232E+04 ]
# >> Step size and gradient norm:
# 		3.891E-04   and   3.751E+03 	[ landmark_points ]
# 		2.244E-03   and   1.771E+03 	[ momenta ]
# ------------------------------------- Iteration: 50 -------------------------------------
# >> Log-likelihood = -8.133E+04 	 [ attachment = -6.889E+04 ; regularity = -1.244E+04 ]
# >> Step size and gradient norm:
# 		5.836E-04   and   4.526E+03 	[ landmark_points ]
# 		3.365E-03   and   2.083E+03 	[ momenta ]
# ------------------------------------- Iteration: 51 -------------------------------------
# >> Log-likelihood = -8.071E+04 	 [ attachment = -6.816E+04 ; regularity = -1.255E+04 ]
# >> Step size and gradient norm:
# 		5.836E-04   and   5.236E+03 	[ landmark_points ]
# 		1.683E-03   and   2.239E+03 	[ momenta ]
# ------------------------------------- Iteration: 52 -------------------------------------
# >> Log-likelihood = -8.041E+04 	 [ attachment = -6.776E+04 ; regularity = -1.265E+04 ]
# >> Step size and gradient norm:
# 		8.754E-04   and   5.949E+03 	[ landmark_points ]
# 		2.524E-03   and   2.365E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		4.377E-04   and   5.949E+03 	[ landmark_points ]
# 		1.262E-03   and   2.365E+03 	[ momenta ]
# ------------------------------------- Iteration: 53 -------------------------------------
# >> Log-likelihood = -7.688E+04 	 [ attachment = -6.416E+04 ; regularity = -1.272E+04 ]
# >> Step size and gradient norm:
# 		6.566E-04   and   3.607E+03 	[ landmark_points ]
# 		1.893E-03   and   1.514E+03 	[ momenta ]
# ------------------------------------- Iteration: 54 -------------------------------------
# >> Log-likelihood = -7.548E+04 	 [ attachment = -6.265E+04 ; regularity = -1.283E+04 ]
# >> Step size and gradient norm:
# 		3.283E-04   and   2.776E+03 	[ landmark_points ]
# 		1.893E-03   and   1.351E+03 	[ momenta ]
# ------------------------------------- Iteration: 55 -------------------------------------
# >> Log-likelihood = -7.430E+04 	 [ attachment = -6.136E+04 ; regularity = -1.294E+04 ]
# >> Step size and gradient norm:
# 		4.924E-04   and   2.473E+03 	[ landmark_points ]
# 		2.840E-03   and   1.246E+03 	[ momenta ]
# ------------------------------------- Iteration: 56 -------------------------------------
# >> Log-likelihood = -7.326E+04 	 [ attachment = -6.024E+04 ; regularity = -1.302E+04 ]
# >> Step size and gradient norm:
# 		4.924E-04   and   2.166E+03 	[ landmark_points ]
# 		1.420E-03   and   1.016E+03 	[ momenta ]
# ------------------------------------- Iteration: 57 -------------------------------------
# >> Log-likelihood = -7.240E+04 	 [ attachment = -5.930E+04 ; regularity = -1.310E+04 ]
# >> Step size and gradient norm:
# 		7.386E-04   and   1.890E+03 	[ landmark_points ]
# 		2.130E-03   and   9.302E+02 	[ momenta ]
# ------------------------------------- Iteration: 58 -------------------------------------
# >> Log-likelihood = -7.197E+04 	 [ attachment = -5.875E+04 ; regularity = -1.322E+04 ]
# >> Step size and gradient norm:
# 		1.108E-03   and   3.168E+03 	[ landmark_points ]
# 		3.195E-03   and   1.299E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		5.540E-04   and   3.168E+03 	[ landmark_points ]
# 		1.597E-03   and   1.299E+03 	[ momenta ]
# ------------------------------------- Iteration: 59 -------------------------------------
# >> Log-likelihood = -7.135E+04 	 [ attachment = -5.806E+04 ; regularity = -1.330E+04 ]
# >> Step size and gradient norm:
# 		8.310E-04   and   3.543E+03 	[ landmark_points ]
# 		2.396E-03   and   1.408E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		4.155E-04   and   3.543E+03 	[ landmark_points ]
# 		1.198E-03   and   1.408E+03 	[ momenta ]
# ------------------------------------- Iteration: 60 -------------------------------------
# >> Log-likelihood = -7.004E+04 	 [ attachment = -5.667E+04 ; regularity = -1.337E+04 ]
# >> Step size and gradient norm:
# 		6.232E-04   and   2.183E+03 	[ landmark_points ]
# 		1.797E-03   and   9.141E+02 	[ momenta ]
# ------------------------------------- Iteration: 61 -------------------------------------
# >> Log-likelihood = -6.960E+04 	 [ attachment = -5.614E+04 ; regularity = -1.345E+04 ]
# >> Step size and gradient norm:
# 		9.348E-04   and   3.181E+03 	[ landmark_points ]
# 		2.695E-03   and   1.166E+03 	[ momenta ]
# >> Step size and gradient norm:
# 		4.674E-04   and   3.181E+03 	[ landmark_points ]
# 		1.348E-03   and   1.166E+03 	[ momenta ]
# ------------------------------------- Iteration: 62 -------------------------------------
# >> Log-likelihood = -6.876E+04 	 [ attachment = -5.523E+04 ; regularity = -1.353E+04 ]
# >> Step size and gradient norm:
# 		7.011E-04   and   2.733E+03 	[ landmark_points ]
# 		2.022E-03   and   9.789E+02 	[ momenta ]
# ------------------------------------- Iteration: 63 -------------------------------------
# >> Log-likelihood = -6.792E+04 	 [ attachment = -5.431E+04 ; regularity = -1.362E+04 ]
# >> Step size and gradient norm:
# 		3.506E-04   and   2.574E+03 	[ landmark_points ]
# 		2.022E-03   and   1.026E+03 	[ momenta ]
# ------------------------------------- Iteration: 64 -------------------------------------
# >> Log-likelihood = -6.716E+04 	 [ attachment = -5.344E+04 ; regularity = -1.373E+04 ]
# >> Step size and gradient norm:
# 		5.258E-04   and   2.525E+03 	[ landmark_points ]
# 		3.032E-03   and   1.028E+03 	[ momenta ]
# ------------------------------------- Iteration: 65 -------------------------------------
# >> Log-likelihood = -6.660E+04 	 [ attachment = -5.281E+04 ; regularity = -1.379E+04 ]
# >> Step size and gradient norm:
# 		5.258E-04   and   3.092E+03 	[ landmark_points ]
# 		1.516E-03   and   1.054E+03 	[ momenta ]
# ------------------------------------- Iteration: 66 -------------------------------------
# >> Log-likelihood = -6.616E+04 	 [ attachment = -5.229E+04 ; regularity = -1.387E+04 ]
# >> Step size and gradient norm:
# 		7.888E-04   and   3.496E+03 	[ landmark_points ]
# 		2.274E-03   and   1.102E+03 	[ momenta ]
# ------------------------------------- Iteration: 67 -------------------------------------
# >> Log-likelihood = -6.591E+04 	 [ attachment = -5.196E+04 ; regularity = -1.395E+04 ]
# >> Step size and gradient norm:
# 		3.944E-04   and   4.153E+03 	[ landmark_points ]
# 		2.274E-03   and   1.378E+03 	[ momenta ]
# ------------------------------------- Iteration: 68 -------------------------------------
# >> Log-likelihood = -6.461E+04 	 [ attachment = -5.061E+04 ; regularity = -1.401E+04 ]
# >> Step size and gradient norm:
# 		3.944E-04   and   2.696E+03 	[ landmark_points ]
# 		1.137E-03   and   8.474E+02 	[ momenta ]
# ------------------------------------- Iteration: 69 -------------------------------------
# >> Log-likelihood = -6.391E+04 	 [ attachment = -4.987E+04 ; regularity = -1.405E+04 ]
# >> Step size and gradient norm:
# 		5.916E-04   and   1.838E+03 	[ landmark_points ]
# 		1.706E-03   and   7.009E+02 	[ momenta ]
# ------------------------------------- Iteration: 70 -------------------------------------
# >> Log-likelihood = -6.351E+04 	 [ attachment = -4.939E+04 ; regularity = -1.413E+04 ]
# >> Step size and gradient norm:
# 		8.874E-04   and   2.533E+03 	[ landmark_points ]
# 		2.558E-03   and   7.951E+02 	[ momenta ]
# ------------------------------------- Iteration: 71 -------------------------------------
# >> Log-likelihood = -6.324E+04 	 [ attachment = -4.903E+04 ; regularity = -1.422E+04 ]
# >> Step size and gradient norm:
# 		4.437E-04   and   3.617E+03 	[ landmark_points ]
# 		2.558E-03   and   1.117E+03 	[ momenta ]
# ------------------------------------- Iteration: 72 -------------------------------------
# >> Log-likelihood = -6.254E+04 	 [ attachment = -4.821E+04 ; regularity = -1.433E+04 ]
# >> Step size and gradient norm:
# 		2.218E-04   and   3.120E+03 	[ landmark_points ]
# 		2.558E-03   and   1.178E+03 	[ momenta ]
# ------------------------------------- Iteration: 73 -------------------------------------
# >> Log-likelihood = -6.218E+04 	 [ attachment = -4.777E+04 ; regularity = -1.442E+04 ]
# >> Step size and gradient norm:
# 		3.328E-04   and   3.372E+03 	[ landmark_points ]
# 		3.838E-03   and   1.361E+03 	[ momenta ]
# ------------------------------------- Iteration: 74 -------------------------------------
# >> Log-likelihood = -6.159E+04 	 [ attachment = -4.712E+04 ; regularity = -1.448E+04 ]
# >> Step size and gradient norm:
# 		3.328E-04   and   3.188E+03 	[ landmark_points ]
# 		1.919E-03   and   1.242E+03 	[ momenta ]
# ------------------------------------- Iteration: 75 -------------------------------------
# >> Log-likelihood = -6.104E+04 	 [ attachment = -4.650E+04 ; regularity = -1.454E+04 ]
# >> Step size and gradient norm:
# 		4.991E-04   and   3.186E+03 	[ landmark_points ]
# 		2.878E-03   and   1.210E+03 	[ momenta ]
# ------------------------------------- Iteration: 76 -------------------------------------
# >> Log-likelihood = -6.057E+04 	 [ attachment = -4.598E+04 ; regularity = -1.458E+04 ]
# >> Step size and gradient norm:
# 		4.991E-04   and   3.407E+03 	[ landmark_points ]
# 		1.439E-03   and   1.087E+03 	[ momenta ]
# ------------------------------------- Iteration: 77 -------------------------------------
# >> Log-likelihood = -6.030E+04 	 [ attachment = -4.568E+04 ; regularity = -1.463E+04 ]
# >> Step size and gradient norm:
# 		7.487E-04   and   3.948E+03 	[ landmark_points ]
# 		2.159E-03   and   1.162E+03 	[ momenta ]
# ------------------------------------- Iteration: 78 -------------------------------------
# >> Log-likelihood = -6.014E+04 	 [ attachment = -4.544E+04 ; regularity = -1.470E+04 ]
# >> Step size and gradient norm:
# 		3.744E-04   and   4.157E+03 	[ landmark_points ]
# 		2.159E-03   and   1.367E+03 	[ momenta ]
# ------------------------------------- Iteration: 79 -------------------------------------
# >> Log-likelihood = -5.890E+04 	 [ attachment = -4.418E+04 ; regularity = -1.473E+04 ]
# >> Step size and gradient norm:
# 		3.744E-04   and   2.806E+03 	[ landmark_points ]
# 		1.079E-03   and   7.918E+02 	[ momenta ]
# ------------------------------------- Iteration: 80 -------------------------------------
# >> Log-likelihood = -5.826E+04 	 [ attachment = -4.350E+04 ; regularity = -1.476E+04 ]
# >> Step size and gradient norm:
# 		5.615E-04   and   1.572E+03 	[ landmark_points ]
# 		1.619E-03   and   6.153E+02 	[ momenta ]
# ------------------------------------- Iteration: 81 -------------------------------------
# >> Log-likelihood = -5.796E+04 	 [ attachment = -4.315E+04 ; regularity = -1.481E+04 ]
# >> Step size and gradient norm:
# 		8.423E-04   and   2.386E+03 	[ landmark_points ]
# 		2.429E-03   and   7.080E+02 	[ momenta ]
# ------------------------------------- Iteration: 82 -------------------------------------
# >> Log-likelihood = -5.770E+04 	 [ attachment = -4.280E+04 ; regularity = -1.490E+04 ]
# >> Step size and gradient norm:
# 		4.211E-04   and   2.836E+03 	[ landmark_points ]
# 		2.429E-03   and   9.439E+02 	[ momenta ]
# ------------------------------------- Iteration: 83 -------------------------------------
# >> Log-likelihood = -5.702E+04 	 [ attachment = -4.205E+04 ; regularity = -1.497E+04 ]
# >> Step size and gradient norm:
# 		2.106E-04   and   2.428E+03 	[ landmark_points ]
# 		2.429E-03   and   9.350E+02 	[ momenta ]
# ------------------------------------- Iteration: 84 -------------------------------------
# >> Log-likelihood = -5.653E+04 	 [ attachment = -4.149E+04 ; regularity = -1.504E+04 ]
# >> Step size and gradient norm:
# 		3.159E-04   and   2.184E+03 	[ landmark_points ]
# 		3.643E-03   and   9.623E+02 	[ momenta ]
# ------------------------------------- Iteration: 85 -------------------------------------
# >> Log-likelihood = -5.593E+04 	 [ attachment = -4.082E+04 ; regularity = -1.510E+04 ]
# >> Step size and gradient norm:
# 		3.159E-04   and   2.119E+03 	[ landmark_points ]
# 		1.821E-03   and   8.580E+02 	[ momenta ]
# ------------------------------------- Iteration: 86 -------------------------------------
# >> Log-likelihood = -5.537E+04 	 [ attachment = -4.020E+04 ; regularity = -1.516E+04 ]
# >> Step size and gradient norm:
# 		4.738E-04   and   1.714E+03 	[ landmark_points ]
# 		2.732E-03   and   7.734E+02 	[ momenta ]
# ------------------------------------- Iteration: 87 -------------------------------------
# >> Log-likelihood = -5.491E+04 	 [ attachment = -3.970E+04 ; regularity = -1.521E+04 ]
# >> Step size and gradient norm:
# 		4.738E-04   and   1.861E+03 	[ landmark_points ]
# 		1.366E-03   and   7.027E+02 	[ momenta ]
# ------------------------------------- Iteration: 88 -------------------------------------
# >> Log-likelihood = -5.457E+04 	 [ attachment = -3.931E+04 ; regularity = -1.526E+04 ]
# >> Step size and gradient norm:
# 		7.107E-04   and   1.778E+03 	[ landmark_points ]
# 		2.049E-03   and   6.729E+02 	[ momenta ]
# ------------------------------------- Iteration: 89 -------------------------------------
# >> Log-likelihood = -5.413E+04 	 [ attachment = -3.881E+04 ; regularity = -1.532E+04 ]
# >> Step size and gradient norm:
# 		3.553E-04   and   1.841E+03 	[ landmark_points ]
# 		2.049E-03   and   7.294E+02 	[ momenta ]
# ------------------------------------- Iteration: 90 -------------------------------------
# >> Log-likelihood = -5.375E+04 	 [ attachment = -3.836E+04 ; regularity = -1.539E+04 ]
# >> Step size and gradient norm:
# 		5.330E-04   and   1.910E+03 	[ landmark_points ]
# 		3.074E-03   and   7.508E+02 	[ momenta ]
# ------------------------------------- Iteration: 91 -------------------------------------
# >> Log-likelihood = -5.354E+04 	 [ attachment = -3.809E+04 ; regularity = -1.544E+04 ]
# >> Step size and gradient norm:
# 		5.330E-04   and   2.526E+03 	[ landmark_points ]
# 		1.537E-03   and   8.445E+02 	[ momenta ]
# ------------------------------------- Iteration: 92 -------------------------------------
# >> Log-likelihood = -5.345E+04 	 [ attachment = -3.796E+04 ; regularity = -1.549E+04 ]
# >> Step size and gradient norm:
# 		7.995E-04   and   3.113E+03 	[ landmark_points ]
# 		2.305E-03   and   9.681E+02 	[ momenta ]
# >> Step size and gradient norm:
# 		3.998E-04   and   3.113E+03 	[ landmark_points ]
# 		1.153E-03   and   9.681E+02 	[ momenta ]
# ------------------------------------- Iteration: 93 -------------------------------------
# >> Log-likelihood = -5.278E+04 	 [ attachment = -3.725E+04 ; regularity = -1.553E+04 ]
# >> Step size and gradient norm:
# 		5.996E-04   and   2.239E+03 	[ landmark_points ]
# 		1.729E-03   and   7.500E+02 	[ momenta ]
# ------------------------------------- Iteration: 94 -------------------------------------
# >> Log-likelihood = -5.230E+04 	 [ attachment = -3.672E+04 ; regularity = -1.558E+04 ]
# >> Step size and gradient norm:
# 		2.998E-04   and   1.490E+03 	[ landmark_points ]
# 		1.729E-03   and   6.374E+02 	[ momenta ]
# ------------------------------------- Iteration: 95 -------------------------------------
# >> Log-likelihood = -5.187E+04 	 [ attachment = -3.623E+04 ; regularity = -1.564E+04 ]
# >> Step size and gradient norm:
# 		4.497E-04   and   1.262E+03 	[ landmark_points ]
# 		2.593E-03   and   5.580E+02 	[ momenta ]
# ------------------------------------- Iteration: 96 -------------------------------------
# >> Log-likelihood = -5.164E+04 	 [ attachment = -3.593E+04 ; regularity = -1.571E+04 ]
# >> Step size and gradient norm:
# 		6.746E-04   and   1.962E+03 	[ landmark_points ]
# 		3.890E-03   and   7.585E+02 	[ momenta ]
# >> Step size and gradient norm:
# 		3.373E-04   and   1.962E+03 	[ landmark_points ]
# 		1.945E-03   and   7.585E+02 	[ momenta ]
# ------------------------------------- Iteration: 97 -------------------------------------
# >> Log-likelihood = -5.135E+04 	 [ attachment = -3.557E+04 ; regularity = -1.579E+04 ]
# >> Step size and gradient norm:
# 		5.059E-04   and   2.004E+03 	[ landmark_points ]
# 		2.918E-03   and   8.108E+02 	[ momenta ]
# ------------------------------------- Iteration: 98 -------------------------------------
# >> Log-likelihood = -5.123E+04 	 [ attachment = -3.541E+04 ; regularity = -1.581E+04 ]
# >> Step size and gradient norm:
# 		5.059E-04   and   2.552E+03 	[ landmark_points ]
# 		1.459E-03   and   8.021E+02 	[ momenta ]
# Tolerance threshold met. Stopping the optimization process.
# >> Estimation took: 03 minutes and 49 seconds

# %% [markdown]
# ## Plot results

# %%
#### LOAD RELEVANT INPUT DATA
import deformetrica as dfca

path_to_template__ini = template_specifications['bike']['filename']
template_points__ini, dimension, template_connectivity__ini = dfca.io.DeformableObjectReader.read_file(path_to_template__ini, extract_connectivity=True)

#### LOAD RELEVANT OUTPUT DATA

fixed_effects = model.fixed_effects
template_points__est = fixed_effects['template_data']['landmark_points']
control_points__est = fixed_effects['control_points']
momenta__est = fixed_effects['momenta']

#### PLOT INITIAL AND ESTIMATED TEMPLATES
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib import cm
from math import sqrt
import pandas as pd
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

def legend_without_duplicate_labels(ax):
    handles, labels = ax.get_legend_handles_labels()
    unique = [(h, l) for i, (h, l) in enumerate(zip(handles, labels)) if l not in labels[:i]]
    ax.legend(*zip(*unique))

figsize = 3
f = plt.figure(figsize=(7*figsize, 1*figsize))
gs = gridspec.GridSpec(1, 3, width_ratios=[5, 5, 6])

# Initial template
ax = plt.subplot(gs[0, 0])
p = template_points__ini
c = template_connectivity__ini
ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], linewidth=2, color='red', label='Initial')

# Estimated template
p = template_points__est
ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], linewidth=2, color='blue', label='Estimated')
legend_without_duplicate_labels(ax) #ax.legend(loc='upper left')
ax.invert_yaxis();
ax.set_title('Initial & Estimated template')

# Estimated template and momenta
ax = plt.subplot(gs[0, 1])
x = control_points__est
ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], 'k', linewidth=4)
cmap = cm.get_cmap('tab10')
for i, m in enumerate(momenta__est):
    color = cmap(i % 10)[:3]
    ax.quiver(x[:,0], x[:,1], m[:,0], m[:,1], color=color, width=0.01, scale=75)
ax.invert_yaxis();
ax.set_title('Estimated template and momenta')

# Estimated template and standard deviation of momenta
ax = plt.subplot(gs[0, 2])
x = control_points__est
ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], 'k', linewidth=1)
cmap = cm.get_cmap('tab10')

list_of_momenta =  [[] for i in range(len(momenta__est[0]))]
for i, m in enumerate(momenta__est):
    for j in range(len(m)):
        list_of_momenta[j].append(abs(sqrt(m[j,0] ** 2 + m[j,1] ** 2)))
        
standard_deviation_momenta = [pd.DataFrame(i).describe()[0]['std'] for i in list_of_momenta]
momenta = ax.scatter(x[:,0], x[:,1], s=75, c=standard_deviation_momenta[:], cmap='Reds')
plt.colorbar(momenta)
ax.invert_yaxis();
ax.set_title('Estimated template and standard deviation of momenta') 

#### PLOT RAW VERSUS RECONSTRUCTED DATA
import torch 

figsize = 5
f = plt.figure(figsize=(10*figsize, 1*figsize))
gs = gridspec.GridSpec(1, 5)

for i, momentum__est in enumerate(momenta__est): 
    ax = plt.subplot(gs[0, i])
    color = cmap(i % 10)[:3]
  
    # Load and plot raw target. 
    path_to_target__raw = dataset_specifications['dataset_filenames'][i][0]['bike']
    target_id = dataset_specifications['subject_ids'][i]
    target_points__raw, _, target_connectivity__raw = dfca.io.DeformableObjectReader.read_file(path_to_target__raw, extract_connectivity=True)

    p = target_points__raw
    c = target_connectivity__raw
    ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], 'k', linewidth=2)
    ax.set_title(target_id)
  
    # Compute and plot the reconstruction of the target. 
    model.exponential.set_initial_momenta(torch.from_numpy(momentum__est).to(torch.float32))
    model.exponential.update()
    target_points__rec = model.exponential.get_template_points()['landmark_points'].detach().cpu().numpy()
  
    p = target_points__rec
    c = template_connectivity__ini
    ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], color=color, linewidth=2)
    ax.invert_yaxis();

plt.style.use('default')
plt.show()
